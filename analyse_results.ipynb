# %%
from matplotlib import pyplot as plt
import pickle



#Load a results file

with open('res/CAquantum2023-11-16 09:12:31.293443.pkl', 'rb') as handle:
    data = pickle.load(handle)

# %%
print(data.keys())
# Out:
# dict_keys(['overlap', 'time', 'timesteps', 'magnetization', 'entropy', 'bond_dimension', 'bond_max', 'L', 'dt', 'nsteps', 'dens', 'g', 'gamma', 'model', 'steadystate', 'fstate'])

# %%
# Plot the number density

plt.imshow(data['magnetization'])

# %%
# Plot entropy

plt.imshow(data['entropy'])

# %%
plt.plot(data['overlap'])
